# %%
import numpy as np

# %% [markdown]
# # 배열의 정보 확인

# %%
A = np.array([1, 2, 3, 4])

# 배열의 차원 확인
print(A.ndim)

# 배열의 모양(shape) 확인
print(A.shape)
# Out:
# 1
# (4,)

# %%
B = np.array([[1, 2],
              [3, 4],
              [5, 6]])

print(B.ndim)
print(B.shape)
# Out:
# 2
# (3, 2)

# %%
A = np.array([[1, 2],
              [3, 4],
              [5, 6]])

B = np.array([[10, 11],
              [12, 13],
              [14, 15]])

# %%
A @ B.T # (3 x 2) @ ( 3 x 2 )^T -> (3 x 2) @ (2 x 3) ===> (3 x 3)
# Out:
# array([[ 32,  38,  44],
#        [ 74,  88, 102],
#        [116, 138, 160]])

# %%
A.T @ B
# Out:
# array([[116, 125],
#        [152, 164]])
