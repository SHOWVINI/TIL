# %% [markdown]
# # 1. Features of Jupyter Notebook

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
x = 100

# %%
x = x+100
print(x)
# Out:
# 200

# %%
import time # python module
print("Sleeping")
time.sleep(30) # sleep for a while; interrupt me!
print("Done Sleeping")
# Out:
# Sleeping
# Done Sleeping

# %% [markdown]
# # 2. Markdowns
# # Title1
# ## Title2
# - bulletpoint
# 1. numbering
#
# ### horizontal line
# ---
# <i>italic font</i>
#
# <b>bold font</b>
#
# ### Code snippets
#
# ```
# x = 3
# x1 = x + 1
# ```

# %%
import numpy as np

arr = np.ndarray(shape=(3, 3))  # 3x3 배열 생성
print(arr)
# Out:
# [[ 1.27189941e-30 -2.54379882e-30  6.35949704e-31]
#  [-2.54379882e-30  5.53276243e-30 -1.71706420e-30]
#  [ 6.35949704e-31 -1.71706420e-30  9.85722042e-31]]

# %%
x = 1
y = 4
z = y/(1-x)

# %%
import numpy as np
import math
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Fills and Alpha Example")
plt.show()

x = [1, 2, 4, 5, 7, 9];
y = [2, 3, 6, 7, 8, 10];
plt.scatter(x,y)
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# ## 3. Convenient cloud-based development using Colab

# %% [markdown]
# Mount google drive

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# check the contents
# !ls ./drive/MyDrive -la

# %%
# example of using matplotlib to display an image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('./drive/MyDrive/prime_cat.png')
plt.imshow(img)

# %%
# upload a file
from google.colab import files

uploaded = files.upload()

# %%
# read the file
import pandas as pd

df = pd.read_csv('./vehicle_prod.csv')
df.head(3)
